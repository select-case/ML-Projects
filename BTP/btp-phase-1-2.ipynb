# %% [markdown]
# <a href="https://www.kaggle.com/code/leotom/btp-phase-1-2?scriptVersionId=165540306" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder

# %%
data_dir = '/kaggle/input/plant-village-dataset/raw'

# %%
import os
from os import listdir

# %%
base_path = "/kaggle/input/plant-village-dataset/raw/color"

# %%
os.listdir(base_path)
# Out:
# ['Grape___healthy',
#  'Orange___Haunglongbing_(Citrus_greening)',
#  'Soybean___healthy',
#  'Potato___healthy',
#  'Corn_(maize)___Northern_Leaf_Blight',
#  'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot',
#  'Peach___healthy',
#  'Apple___Apple_scab',
#  'Apple___Black_rot',
#  'Blueberry___healthy',
#  'Cherry_(including_sour)___Powdery_mildew',
#  'Peach___Bacterial_spot',
#  'Apple___Cedar_apple_rust',
#  'Pepper,_bell___healthy',
#  'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)',
#  'Potato___Late_blight',
#  'Apple___healthy',
#  'Grape___Black_rot',
#  'Potato___Early_blight',
#  'Cherry_(including_sour)___healthy',
#  'Corn_(maize)___Common_rust_',
#  'Grape___Esca_(Black_Measles)',
#  'Raspberry___healthy',
#  'Pepper,_bell___Bacterial_spot',
#  'Corn_(maize)___healthy']

# %%
len(os.listdir(base_path))
# Out:
# 25

# %%
from glob import glob
imagePatches = glob("//kaggle/input/plant-village-dataset/raw/color/*/*.*", recursive=True)

# %%
len(imagePatches)
# Out:
# 30247

# %%
image_path = base_path + "/Tomato_Bacterial_spot/3a5a5fef-8a3a-4f70-ab85-eaf5e3ecf6f2___GCREC_Bact.Sp 3449.JPG"

# %%
dir_name = os.path.dirname(image_path)

# %%
len(dir_name.split("/"))
# Out:
# 7

# %%
from fastai import *
from fastai.vision import *
from fastai.vision.data import *

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import auc,roc_curve

from pathlib import Path

from math import floor

import numpy as np
import tensorflow as tf
from tensorflow import keras
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Layer
import pickle
import os
from tensorflow.keras.utils import img_to_array
from keras.applications.resnet import ResNet50
from keras.layers import GlobalMaxPooling2D, Dense, GlobalAveragePooling2D
from keras.applications.inception_resnet_v2 import preprocess_input
from tensorflow.keras.models import Model
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

default_image_size = tuple((229, 229))
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dir_name.split("/")[6]
# Out:
# 'Tomato_Bacterial_spot'

# %% [markdown]
# ##### IMAGE PROCESSING

# %%
path = Path(base_path)

# %%
path
# Out:
# Path('/kaggle/input/plant-village-dataset/raw/color')

# %%
directory_root = '/kaggle/input/plant-village-dataset/raw/color'

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)
            x = img_to_array(image)
            return x #np.expand_dims(x, axis=0)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    plant_disease_folder_list = listdir(f"{directory_root}")

    for disease_folder in plant_disease_folder_list :
        # remove .DS_Store from list
        if disease_folder == ".DS_Store" :
            plant_disease_folder_list.remove(disease_folder)

    for plant_disease_folder in plant_disease_folder_list:
        print(f"[INFO] Processing {plant_disease_folder} ...")
        plant_disease_image_list = listdir(f"{directory_root}/{plant_disease_folder}/")

        for single_plant_disease_image in plant_disease_image_list :
            if single_plant_disease_image == ".DS_Store" :
                plant_disease_image_list.remove(single_plant_disease_image)

        for image in plant_disease_image_list[:200]:
            image_directory = f"{directory_root}/{plant_disease_folder}/{image}"
            if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                image_list.append(convert_image_to_array(image_directory))
                label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Grape___healthy ...
# [INFO] Processing Orange___Haunglongbing_(Citrus_greening) ...
# [INFO] Processing Soybean___healthy ...
# [INFO] Processing Potato___healthy ...
# [INFO] Processing Corn_(maize)___Northern_Leaf_Blight ...
# [INFO] Processing Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot ...
# [INFO] Processing Peach___healthy ...
# [INFO] Processing Apple___Apple_scab ...
# [INFO] Processing Apple___Black_rot ...
# [INFO] Processing Blueberry___healthy ...
# [INFO] Processing Cherry_(including_sour)___Powdery_mildew ...
# [INFO] Processing Peach___Bacterial_spot ...
# [INFO] Processing Apple___Cedar_apple_rust ...
# [INFO] Processing Pepper,_bell___healthy ...
# [INFO] Processing Grape___Leaf_blight_(Isariopsis_Leaf_Spot) ...
# [INFO] Processing Potato___Late_blight ...
# [INFO] Processing Apple___healthy ...
# [INFO] Processing Grape___Black_rot ...
# [INFO] Processing Potato___Early_blight ...
# [INFO] Processing Cherry_(including_sour)___healthy ...
# [INFO] Processing Corn_(maize)___Common_rust_ ...
# [INFO] Processing Grape___Esca_(Black_Measles) ...
# [INFO] Processing Raspberry___healthy ...
# [INFO] Processing Pepper,_bell___Bacterial_spot ...
# [INFO] Processing Corn_(maize)___healthy ...
# [INFO] Image loading completed

# %%
def get_labels(file_path):
    return os.path.basename(os.path.dirname(file_path))

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)
            x = img_to_array(image)
            return x #np.expand_dims(x, axis=0)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
np_image_list = np.array(image_list, dtype=np.float16)
#print("Total no. of y:{}".format(np_label.shape))
#print("Total no. of images:{}".format(image_list.shape))

softmax_output = len(plant_disease_folder_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)
print(n_classes)
# Out:
# 25

# %%
X_train,X_test,Y_train,Y_test = train_test_split(np_image_list,image_labels,test_size=0.3,random_state=42)

# %%
len(Y_test)
# Out:
# 1486

# %%
Y_test.shape
# Out:
# (1486, 25)

# %%
X_test.shape
# Out:
# (1486, 229, 229, 3)

# %% [markdown]
# ## RESNET

# %%
model = ResNet50(include_top=False,
    weights="imagenet")
X = model.output
X = GlobalMaxPooling2D()(X)
predictions = Dense(softmax_output, activation='softmax')(X)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 3s 0us/step

# %%
aug = ImageDataGenerator(
    rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2,
    zoom_range=0.2,horizontal_flip=True,
    fill_mode="nearest")

# %%
batch_size = 16
epochs = 20
INIT_LR = 1e-3
my_callbacks = [
    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
]

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=10000,
    decay_rate=0.9)

# %%
alpha = 1e-5
opt = tf.keras.optimizers.Adam(learning_rate = lr_schedule)

from keras.optimizers import SGD
opt = SGD(learning_rate=0.001)

Resnet_model = Model(inputs=model.input, outputs=predictions)
Resnet_model.compile(optimizer=opt, loss='categorical_crossentropy',metrics=["accuracy"])

# %%
r = Resnet_model.fit(
    aug.flow(X_train, Y_train, batch_size=16),
    batch_size=batch_size,
    epochs=epochs,
    callbacks=my_callbacks,
    validation_data=(X_test, Y_test),
    shuffle=True
)
# Out:
# Epoch 1/20
# 217/217 [==============================] - 61s 246ms/step - loss: 2.9557 - accuracy: 0.6601 - val_loss: 0.6199 - val_accuracy: 0.8822
# Epoch 2/20
# 217/217 [==============================] - 48s 221ms/step - loss: 0.4368 - accuracy: 0.9137 - val_loss: 0.5461 - val_accuracy: 0.9078
# Epoch 3/20
# 217/217 [==============================] - 48s 221ms/step - loss: 0.3148 - accuracy: 0.9365 - val_loss: 0.2970 - val_accuracy: 0.9441
# Epoch 4/20
# 217/217 [==============================] - 48s 223ms/step - loss: 0.2192 - accuracy: 0.9507 - val_loss: 0.2292 - val_accuracy: 0.9583
# Epoch 5/20
# 217/217 [==============================] - 49s 225ms/step - loss: 0.1626 - accuracy: 0.9674 - val_loss: 0.2292 - val_accuracy: 0.9576
# Epoch 6/20
# 217/217 [==============================] - 50s 231ms/step - loss: 0.1356 - accuracy: 0.9686 - val_loss: 0.2061 - val_accuracy: 0.9630
# Epoch 7/20
# 217/217 [==============================] - 50s 228ms/step - loss: 0.1180 - accuracy: 0.9737 - val_loss: 0.2281 - val_accuracy: 0.9569
# Epoch 8/20
# 217/217 [==============================] - 48s 223ms/step - loss: 0.0690 - accuracy: 0.9815 - val_loss: 0.3233 - val_accuracy: 0.9542
# Epoch 9/20
# 217/217 [==============================] - 48s 222ms/step - loss: 0.0876 - accuracy: 0.9792 - val_loss: 0.1663 - val_accuracy: 0.9690
# Epoch 10/20
# 217/217 [==============================] - 48s 222ms/step - loss: 0.0552 - accuracy: 0.9833 - val_loss: 0.3019 - val_accuracy: 0.9549
# Epoch 11/20
# 217/217 [==============================] - 49s 224ms/step - loss: 0.0481 - accuracy: 0.9873 - val_loss: 0.2267 - val_accuracy: 0.9670
# Epoch 12/20
# 217/217 [==============================] - 49s 225ms/step - loss: 0.0585 - accuracy: 0.9859 - val_loss: 0.1824 - val_accuracy: 0.9670
# Epoch 13/20
# 217/217 [==============================] - 49s 224ms/step - loss: 0.0344 - accuracy: 0.9925 - val_loss: 0.1711 - val_accuracy: 0.9684
# Epoch 14/20
# 217/217 [==============================] - 49s 225ms/step - loss: 0.0478 - accuracy: 0.9893 - val_loss: 0.1304 - val_accuracy: 0.9764
# Epoch 15/20
# 217/217 [==============================] - 49s 223ms/step - loss: 0.0454 - accuracy: 0.9882 - val_loss: 0.1589 - val_accuracy: 0.9704
# Epoch 16/20
# 217/217 [==============================] - 48s 222ms/step - loss: 0.0312 - accuracy: 0.9905 - val_loss: 0.1903 - val_accuracy: 0.9704
# Epoch 17/20
# 217/217 [==============================] - 49s 222ms/step - loss: 0.0546 - accuracy: 0.9867 - val_loss: 0.1385 - val_accuracy: 0.9724
# Epoch 18/20
# 217/217 [==============================] - 49s 224ms/step - loss: 0.0377 - accuracy: 0.9876 - val_loss: 0.1124 - val_accuracy: 0.9764
# Epoch 19/20
# 217/217 [==============================] - 48s 223ms/step - loss: 0.0299 - accuracy: 0.9916 - val_loss: 0.1688 - val_accuracy: 0.9731
# Epoch 20/20
# 217/217 [==============================] - 49s 226ms/step - loss: 0.0428 - accuracy: 0.9893 - val_loss: 0.1267 - val_accuracy: 0.9785

# %%
plt.plot(r.history['accuracy'], label='training acc')
plt.plot(r.history['val_accuracy'], label='validation acc')
plt.xticks([i for i in range(20)])
plt.ylim([0, 1])
plt.legend()
plt.show()
plt.savefig('Accuracy_Plot2')

# %% [markdown]
# ## INCEPTION V3

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input

# %%
model = InceptionV3(include_top=False,
    weights="imagenet")

X = model.output
X = GlobalMaxPooling2D()(X)
predictions = Dense(softmax_output, activation='softmax')(X)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 3s 0us/step

# %%
aug = ImageDataGenerator(
    rotation_range=25, width_shift_range=0.1,
    height_shift_range=0.1, shear_range=0.2,
    zoom_range=0.2,horizontal_flip=True,
    fill_mode="nearest")

# %%
batch_size = 16
epochs = 20
INIT_LR = 1e-3
my_callbacks = [
    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
]

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=10000,
    decay_rate=0.9)

# %%
alpha = 1e-5
opt = tf.keras.optimizers.Adam(learning_rate = lr_schedule)

from keras.optimizers import SGD
opt = SGD(learning_rate=0.001)

Inception_model = Model(inputs=model.input, outputs=predictions)
Inception_model.compile(optimizer=opt, loss='categorical_crossentropy',metrics=["accuracy"])

# %%
r = Inception_model.fit(
    aug.flow(X_train, Y_train, batch_size=16),
    batch_size=batch_size,
    epochs=epochs,
    callbacks=my_callbacks,
    validation_data=(X_test, Y_test),
    shuffle=True
)
# Out:
# Epoch 1/20
# 217/217 [==============================] - 63s 250ms/step - loss: 2.3491 - accuracy: 0.3653 - val_loss: 1.1202 - val_accuracy: 0.6608
# Epoch 2/20
# 217/217 [==============================] - 48s 222ms/step - loss: 0.8270 - accuracy: 0.7464 - val_loss: 0.5419 - val_accuracy: 0.8244
# Epoch 3/20
# 217/217 [==============================] - 49s 224ms/step - loss: 0.5219 - accuracy: 0.8379 - val_loss: 0.3542 - val_accuracy: 0.8829
# Epoch 4/20
# 217/217 [==============================] - 49s 227ms/step - loss: 0.4144 - accuracy: 0.8670 - val_loss: 0.2656 - val_accuracy: 0.9186
# Epoch 5/20
# 217/217 [==============================] - 48s 223ms/step - loss: 0.2919 - accuracy: 0.9088 - val_loss: 0.2360 - val_accuracy: 0.9260
# Epoch 6/20
# 217/217 [==============================] - 49s 225ms/step - loss: 0.2572 - accuracy: 0.9175 - val_loss: 0.1894 - val_accuracy: 0.9415
# Epoch 7/20
# 217/217 [==============================] - 48s 222ms/step - loss: 0.2100 - accuracy: 0.9345 - val_loss: 0.1745 - val_accuracy: 0.9515
# Epoch 8/20
# 217/217 [==============================] - 49s 223ms/step - loss: 0.1994 - accuracy: 0.9348 - val_loss: 0.1635 - val_accuracy: 0.9515
# Epoch 9/20
# 217/217 [==============================] - 48s 222ms/step - loss: 0.1774 - accuracy: 0.9455 - val_loss: 0.1661 - val_accuracy: 0.9489
# Epoch 10/20
# 217/217 [==============================] - 48s 223ms/step - loss: 0.1555 - accuracy: 0.9478 - val_loss: 0.1459 - val_accuracy: 0.9502
# Epoch 11/20
# 217/217 [==============================] - 48s 221ms/step - loss: 0.1506 - accuracy: 0.9504 - val_loss: 0.1462 - val_accuracy: 0.9542
# Epoch 12/20
# 217/217 [==============================] - 48s 221ms/step - loss: 0.1352 - accuracy: 0.9596 - val_loss: 0.1417 - val_accuracy: 0.9509
# Epoch 13/20
# 217/217 [==============================] - 48s 223ms/step - loss: 0.1158 - accuracy: 0.9625 - val_loss: 0.1248 - val_accuracy: 0.9623
# Epoch 14/20
# 217/217 [==============================] - 49s 223ms/step - loss: 0.1125 - accuracy: 0.9651 - val_loss: 0.1230 - val_accuracy: 0.9583
# Epoch 15/20
# 217/217 [==============================] - 49s 225ms/step - loss: 0.1030 - accuracy: 0.9668 - val_loss: 0.1268 - val_accuracy: 0.9596
# Epoch 16/20
# 217/217 [==============================] - 49s 224ms/step - loss: 0.0990 - accuracy: 0.9662 - val_loss: 0.1225 - val_accuracy: 0.9610
# Epoch 17/20
# 217/217 [==============================] - 48s 221ms/step - loss: 0.0961 - accuracy: 0.9694 - val_loss: 0.1185 - val_accuracy: 0.9590
# Epoch 18/20
# 217/217 [==============================] - 48s 221ms/step - loss: 0.0801 - accuracy: 0.9729 - val_loss: 0.1095 - val_accuracy: 0.9643
# Epoch 19/20
# 217/217 [==============================] - 48s 221ms/step - loss: 0.0804 - accuracy: 0.9743 - val_loss: 0.1132 - val_accuracy: 0.9616
# Epoch 20/20
# 217/217 [==============================] - 48s 221ms/step - loss: 0.0879 - accuracy: 0.9691 - val_loss: 0.1049 - val_accuracy: 0.9610

# %%
plt.plot(r.history['accuracy'], label='training acc')
plt.plot(r.history['val_accuracy'], label='validation acc')
plt.xticks([i for i in range(20)])
plt.ylim([0, 1])
plt.legend()
plt.show()
plt.savefig('Accuracy_Plot2')

# %% [markdown]
# ## BANANA NEW

# %%
base_path_new_dataset = "/kaggle/input/banana-new/BANANA DISEASE"

# %%
from glob import glob
imagePatches = glob("/kaggle/input/banana-new/BANANA DISEASE/*/*.*", recursive=True)

# %%
len(imagePatches)
# Out:
# 6189

# %%
from fastai import *
from fastai.vision import *
from fastai.vision.data import *

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import auc,roc_curve

from pathlib import Path

from math import floor

import numpy as np
import tensorflow as tf
from tensorflow import keras
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Layer
import pickle
import os
from tensorflow.keras.utils import img_to_array
from keras.applications.resnet import ResNet50
from keras.layers import GlobalMaxPooling2D, Dense, GlobalAveragePooling2D
from keras.applications.inception_resnet_v2 import preprocess_input
from tensorflow.keras.models import Model
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

default_image_size = tuple((229, 229))

# %%
path = Path(base_path_new_dataset)

# %%
path
# Out:
# Path('/kaggle/input/banana-new/BANANA DISEASE')

# %%
directory_root = '/kaggle/input/banana-new/BANANA DISEASE'

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)
            x = img_to_array(image)
            return x #np.expand_dims(x, axis=0)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
image_list, label_list = [], []
try:
    print("[INFO] Loading images ...")
    root_dir = listdir(directory_root)
    for directory in root_dir :
        # remove .DS_Store from list
        if directory == ".DS_Store" :
            root_dir.remove(directory)

    plant_disease_folder_list = listdir(f"{directory_root}")

    for disease_folder in plant_disease_folder_list :
        # remove .DS_Store from list
        if disease_folder == ".DS_Store" :
            plant_disease_folder_list.remove(disease_folder)

    for plant_disease_folder in plant_disease_folder_list:
        print(f"[INFO] Processing {plant_disease_folder} ...")
        plant_disease_image_list = listdir(f"{directory_root}/{plant_disease_folder}/")

        for single_plant_disease_image in plant_disease_image_list :
            if single_plant_disease_image == ".DS_Store" :
                plant_disease_image_list.remove(single_plant_disease_image)

        for image in plant_disease_image_list[:200]:
            image_directory = f"{directory_root}/{plant_disease_folder}/{image}"
            if image_directory.endswith(".jpg") == True or image_directory.endswith(".JPG") == True:
                image_list.append(convert_image_to_array(image_directory))
                label_list.append(plant_disease_folder)
    print("[INFO] Image loading completed")
except Exception as e:
    print(f"Error : {e}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing RESIZED BANANA APHIDS ...
# [INFO] Processing BRACT MOSAIC ...
# [INFO] Processing RESIZED PSEUDOSTEM WEEVIL ...
# [INFO] Processing MOKO ...
# [INFO] Processing RESIZED BANANA FRUIT- SCARRING BEETLE ...
# [INFO] Processing RESIZED BACTERIAL SOFT ROT ...
# [INFO] Processing HEALTHY ...
# [INFO] Processing RESIZED BLACK SIGATOKA ...
# [INFO] Processing RESIZED PANAMA DISEASE ...
# [INFO] Processing RESIZED YELLOW SIGATOKA ...
# [INFO] Image loading completed

# %%
np_image_list = np.array(image_list, dtype=np.float16)
#print("Total no. of y:{}".format(np_label.shape))
#print("Total no. of images:{}".format(image_list.shape))

softmax_output = len(plant_disease_folder_list)

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)
pickle.dump(label_binarizer,open('label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)
print(n_classes)
# Out:
# 10

# %%
X_train,X_test,Y_train,Y_test = train_test_split(np_image_list,image_labels,test_size=0.3,random_state=42)

# %%
X_test.shape
# Out:
# (527, 229, 229, 3)

# %%
model = ResNet50(include_top=False,
    weights="imagenet")
X = model.output
X = GlobalMaxPooling2D()(X)
predictions = Dense(softmax_output, activation='softmax')(X)

# %%
Resnet_model = Model(inputs=model.input, outputs=predictions)
Resnet_model.compile(optimizer=opt, loss='categorical_crossentropy',metrics=["accuracy"])

# %%
r = Resnet_model.fit(
    aug.flow(X_train, Y_train, batch_size=16),
    batch_size=batch_size,
    epochs=10,
    callbacks=my_callbacks,

    shuffle=True
)
# Out:
# Epoch 1/10
# 77/77 [==============================] - 23s 223ms/step - loss: 4.6006 - accuracy: 0.5655
# Epoch 2/10
# 77/77 [==============================] - 16s 208ms/step - loss: 1.0405 - accuracy: 0.8275
# Epoch 3/10
# 77/77 [==============================] - 16s 212ms/step - loss: 0.6148 - accuracy: 0.8950
# Epoch 4/10
# 77/77 [==============================] - 18s 226ms/step - loss: 0.4851 - accuracy: 0.9129
# Epoch 5/10
# 77/77 [==============================] - 17s 215ms/step - loss: 0.3799 - accuracy: 0.9276
# Epoch 6/10
# 77/77 [==============================] - 17s 218ms/step - loss: 0.2137 - accuracy: 0.9609
# Epoch 7/10
# 77/77 [==============================] - 17s 218ms/step - loss: 0.3239 - accuracy: 0.9390
# Epoch 8/10
# 77/77 [==============================] - 17s 213ms/step - loss: 0.2317 - accuracy: 0.9536
# Epoch 9/10
# 77/77 [==============================] - 17s 213ms/step - loss: 0.1719 - accuracy: 0.9601
# Epoch 10/10
# 77/77 [==============================] - 17s 214ms/step - loss: 0.2334 - accuracy: 0.9569

# %%
true_classes = np.argmax(Y_test, axis=1)

# %%
predictions = Resnet_model.predict(X_test)
predicted_classes = np.argmax(predictions, axis=1)
# Out:
# 17/17 [==============================] - 3s 84ms/step

# %%
true_classes
# Out:
# array([0, 8, 8, 8, 3, 1, 1, 2, 6, 1, 4, 0, 0, 4, 3, 7, 8, 8, 1, 6, 4, 8,
#        6, 2, 6, 5, 9, 9, 0, 4, 6, 5, 6, 2, 2, 5, 4, 4, 0, 8, 9, 4, 0, 3,
#        8, 9, 7, 2, 5, 4, 2, 6, 2, 5, 3, 6, 9, 7, 9, 0, 4, 0, 5, 6, 1, 0,
#        0, 6, 9, 2, 2, 8, 5, 9, 6, 4, 6, 3, 9, 1, 3, 7, 3, 8, 3, 6, 5, 9,
#        3, 9, 3, 8, 1, 1, 6, 6, 6, 1, 8, 6, 1, 8, 6, 8, 3, 1, 8, 2, 8, 2,
#        2, 2, 9, 8, 2, 2, 0, 0, 0, 0, 5, 8, 2, 4, 1, 8, 6, 8, 9, 3, 8, 1,
#        0, 0, 9, 7, 4, 0, 6, 4, 4, 5, 8, 6, 0, 0, 8, 1, 0, 8, 3, 4, 7, 3,
#        7, 9, 0, 3, 2, 4, 3, 9, 0, 9, 6, 4, 2, 5, 0, 2, 4, 5, 4, 2, 5, 9,
#        8, 2, 9, 9, 4, 3, 8, 8, 8, 5, 3, 4, 8, 5, 9, 4, 6, 2, 1, 5, 3, 4,
#        1, 8, 0, 3, 0, 2, 9, 9, 4, 5, 9, 1, 0, 8, 9, 9, 0, 8, 0, 5, 0, 8,
#        7, 7, 6, 1, 6, 0, 8, 3, 6, 4, 1, 9, 4, 8, 2, 6, 6, 1, 8, 8, 2, 0,
#        9, 8, 4, 0, 7, 0, 2, 1, 6, 6, 8, 1, 5, 0, 3, 6, 0, 5, 9, 6, 5, 5,
#        1, 4, 2, 0, 4, 2, 8, 7, 1, 8, 0, 0, 9, 1, 6, 8, 8, 7, 8, 4, 6, 9,
#        9, 0, 1, 9, 0, 4, 2, 0, 2, 1, 3, 8, 1, 3, 6, 6, 0, 7, 7, 2, 6, 2,
#        8, 5, 3, 7, 8, 6, 4, 9, 6, 6, 0, 9, 2, 5, 5, 5, 5, 3, 1, 9, 3, 1,
#        9, 4, 2, 6, 8, 3, 2, 6, 5, 8, 4, 4, 0, 8, 5, 2, 9, 2, 8, 1, 3, 4,
#        6, 2, 1, 9, 7, 3, 2, 9, 2, 0, 3, 0, 4, 3, 1, 3, 4, 4, 0, 1, 0, 4,
#        5, 4, 3, 9, 1, 2, 8, 3, 2, 5, 6, 4, 6, 8, 2, 5, 7, 6, 1, 5, 7, 8,
#        8, 9, 6, 3, 2, 3, 7, 6, 9, 5, 1, 2, 3, 0, 0, 2, 7, 6, 4, 2, 2, 0,
#        4, 8, 5, 7, 1, 6, 0, 4, 5, 0, 5, 4, 5, 9, 3, 2, 3, 6, 3, 7, 3, 3,
#        3, 2, 0, 2, 0, 8, 6, 7, 0, 2, 8, 1, 7, 7, 8, 6, 9, 9, 9, 5, 9, 1,
#        8, 5, 2, 5, 6, 3, 3, 5, 5, 6, 9, 9, 6, 0, 6, 9, 0, 1, 0, 1, 9, 7,
#        9, 9, 1, 6, 0, 3, 9, 8, 4, 5, 9, 2, 3, 6, 0, 8, 8, 0, 8, 3, 6, 9,
#        8, 3, 2, 0, 6, 6, 9, 4, 3, 6, 8, 4, 5, 0, 9, 4, 7, 9, 5, 8, 7])

# %%
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
cm = confusion_matrix(true_classes, predicted_classes)

# Plot the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt="d", cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
